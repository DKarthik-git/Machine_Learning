# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import sklearn.metrics as ms

data=sns.load_dataset("tips")
#print(data.head())

data['sex']=data['sex'].astype('category')
data['sex']=data['sex'].cat.codes
#print(data.head())

x = data[['total_bill', 'sex']]
y = data['tip']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

regr=LinearRegression()
regr.fit(x_train,y_train)
y_pred=regr.predict(x_test)
print(regr.score(x_train,y_train))

x1=float(input('Enter Total_bill ='))
x2=float(input('Enter sex M=1 / F=0 = '))
user_input = pd.DataFrame({'total_bill': [x1], 'sex': [x2]})
prediction = regr.predict(user_input)

print(data[['total_bill', 'tip']])
sns.lmplot(x="total_bill",y="tip",data=data)
plt.show()

print(data[['sex', 'tip']])
sns.lmplot(x="sex",y="tip",data=data)
plt.show()

print(data[['total_bill', 'sex']])
sns.lmplot(x="total_bill",y="sex",data=data)
plt.show()

print("r2 score =",round(ms.r2_score(y_test,y_pred),2))
# Out:
# 0.46730250882898927
# Total_bill =50
# sex =1
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]
#      sex   tip
# 0      1  1.01
# 1      0  1.66
# 2      0  3.50
# 3      0  3.31
# 4      1  3.61
# ..   ...   ...
# 239    0  5.92
# 240    1  2.00
# 241    0  2.00
# 242    0  1.75
# 243    1  3.00
#
# [244 rows x 2 columns]
#      total_bill  sex
# 0         16.99    1
# 1         10.34    0
# 2         21.01    0
# 3         23.68    0
# 4         24.59    1
# ..          ...  ...
# 239       29.03    0
# 240       27.18    1
# 241       22.67    0
# 242       17.82    0
# 243       18.78    1
#
# [244 rows x 2 columns]
# r2 score = 0.39
